# %%
# !git clone https://github.com/ultralytics/google-images-download
#!cd './google-images-download/'
# !pip install -U -r ./google-images-download/requirements.txt
# !wget https://chromedriver.storage.googleapis.com/2.41/chromedriver_linux64.zip -O ./chromedriver_linux64.zip
# !unzip ./chromedriver_linux64.zip chromedriver
#!sudo ln -s chromedriver /usr/local/bin/
#!ls
# Out:
# Cloning into 'google-images-download'...
# remote: Enumerating objects: 715, done.
# remote: Total 715 (delta 0), reused 0 (delta 0), pack-reused 715
# Receiving objects: 100% (715/715), 296.07 KiB | 423.00 KiB/s, done.
# Resolving deltas: 100% (400/400), done.
# ...
#      |████████████████████████████████| 71kB 2.0MB/s
# ...
#      |████████████████████████████████| 911kB 7.0MB/s
# ...
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# ...
# --2020-08-26 16:54:02--  https://chromedriver.storage.googleapis.com/2.41/chromedriver_linux64.zip
# Resolving chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)... 108.177.125.128, 2404:6800:4008:c01::80
# Connecting to chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)|108.177.125.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3944714 (3.8M) [application/zip]
# Saving to: ‘./chromedriver_linux64.zip’
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !wget -q -O - https://dl-ssl.google.com/linux/linux_signing_key.pub | sudo apt-key add -
# !echo 'deb [arch=amd64] http://dl.google.com/linux/chrome/deb/ stable main' | sudo tee /etc/apt/sources.list.d/google-chrome.list
# !sudo apt-get update
# !sudo apt-get install google-chrome-stable
# Out:
# OK
# deb [arch=amd64] http://dl.google.com/linux/chrome/deb/ stable main
# Get:1 http://dl.google.com/linux/chrome/deb stable InRelease [1,811 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Get:3 http://dl.google.com/linux/chrome/deb stable/main amd64 Packages [1,116 B]
# Ign:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [95.3 kB]
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# ...

# %% [markdown]
# В текущей папке должен появиться файл chromedriver, а в системе установиться google chrome

# %%
# !sudo python ./google-images-download/bing_scraper.py --search 'картинка' --limit 1500 --download --chromedriver ./chromedriver
# Out:
# Searching for https://www.bing.com/images/search?q=картинка
# ...
# 1/1500 https://s00.yaplakal.com/pics/pics_original/4/1/0/6269014.jpg
# 2/1500 https://s00.yaplakal.com/pics/pics_original/9/2/3/8037329.jpg
# 3/1500 https://i.ytimg.com/vi/4i4bh4OZwzg/maxresdefault.jpg
# 4/1500 https://bipbap.ru/wp-content/uploads/2017/09/27017-nature-is-this-real-1.jpg
# 5/1500 https://i.ytimg.com/vi/dx4c3ZwdDA8/maxresdefault.jpg
# 6/1500 https://i.ytimg.com/vi/qBNi4PlyPcQ/maxresdefault.jpg
# 7/1500 https://i.ytimg.com/vi/mcMJU1Q4JGY/maxresdefault.jpg
# 8/1500 https://i.ytimg.com/vi/QvMvkRtwSDk/maxresdefault.jpg
# 9/1500 https://i.ytimg.com/vi/5J4gYC-cBWo/maxresdefault.jpg
# 10/1500 https://i.ytimg.com/vi/mF9TuiUMdvQ/hqdefault.jpg
# 11/1500 https://i.ytimg.com/vi/0JfbBXzPg0Y/maxresdefault.jpg
# 12/1500 https://i.ytimg.com/vi/4Bo6V7eHvlA/hqdefault.jpg
# 13/1500 https://i.ytimg.com/vi/FTHufJuCbIE/maxresdefault.jpg
# 14/1500 https://i.ytimg.com/vi/f9AwrAUNRIU/maxresdefault.jpg
# ...

# %%
# !zip -r images.zip ./images
# Out:
#   adding: images/ (stored 0%)
#   adding: images/картинка/ (stored 0%)
#   adding: images/картинка/135.hqdefault.jpg (deflated 3%)
#   adding: images/картинка/8.maxresdefault.jpg (deflated 0%)
#   adding: images/картинка/215.1430669577_pozdravleniya-na-9-maya-127.jpg (deflated 4%)
#   adding: images/картинка/364.fon-multfilmy-panda_kung-fu-pandy-zhivotnye-17064.jpg (deflated 23%)
#   adding: images/картинка/240.d62a972e632e69f95e3528d541b86265.jpg (deflated 1%)
#   adding: images/картинка/102.maxresdefault.jpg (deflated 4%)
#   adding: images/картинка/237.kartinki_s_polevimi_tsvetami_krasivie.jpg (deflated 1%)
#   adding: images/картинка/377.5a7982179aac871e2d233c06946000d7.jpg (deflated 1%)
#   adding: images/картинка/218.universe-planet-nebula-stars-space-1206-resized.jpg (deflated 0%)
#   adding: images/картинка/349.a89d95e21e2ab2af50cf1d3b49a46b81.gif (deflated 1%)
#   adding: images/картинка/43.maxresdefault.jpg (deflated 0%)
# ...
